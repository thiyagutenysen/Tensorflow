# %%
import tensorflow as tf
import tensorflowjs as tfjs

# %%
vgg16_model = tf.keras.applications.vgg16.VGG16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step

# %%
tfjs.converters.save_keras_model(vgg16_model, 'VGG16')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflowjs/converters/keras_h5_conversion.py:123: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   return h5py.File(h5file)

# %%
# !zip -r ./vgg.zip ./VGG16/
# Out:
#   adding: VGG16/ (stored 0%)
#   adding: VGG16/group1-shard116of132.bin (deflated 7%)
#   adding: VGG16/group1-shard105of132.bin (deflated 7%)
#   adding: VGG16/group1-shard114of132.bin (deflated 7%)
#   adding: VGG16/group1-shard4of132.bin (deflated 7%)
#   adding: VGG16/group1-shard99of132.bin (deflated 7%)
#   adding: VGG16/group1-shard70of132.bin (deflated 7%)
#   adding: VGG16/group1-shard22of132.bin (deflated 7%)
#   adding: VGG16/group1-shard130of132.bin (deflated 7%)
#   adding: VGG16/group1-shard16of132.bin (deflated 7%)
#   adding: VGG16/group1-shard109of132.bin (deflated 7%)
#   adding: VGG16/group1-shard55of132.bin (deflated 7%)
#   adding: VGG16/group1-shard107of132.bin (deflated 7%)
#   adding: VGG16/group1-shard121of132.bin (deflated 7%)
#   adding: VGG16/group1-shard77of132.bin (deflated 7%)
#   adding: VGG16/group1-shard100of132.bin (deflated 7%)
#   adding: VGG16/model.json (deflated 91%)
#   adding: VGG16/group1-shard78of132.bin (deflated 7%)
#   adding: VGG16/group1-shard37of132.bin (deflated 7%)
#   adding: VGG16/group1-shard11of132.bin (deflated 7%)
#   adding: VGG16/group1-shard104of132.bin (deflated 7%)
#   adding: VGG16/group1-shard108of132.bin (deflated 7%)
#   adding: VGG16/group1-shard74of132.bin (deflated 7%)
#   adding: VGG16/group1-shard120of132.bin (deflated 7%)
#   adding: VGG16/group1-shard128of132.bin (deflated 7%)
#   adding: VGG16/group1-shard84of132.bin (deflated 7%)
#   adding: VGG16/group1-shard8of132.bin (deflated 7%)
#   adding: VGG16/group1-shard67of132.bin (deflated 7%)
#   adding: VGG16/group1-shard7of132.bin (deflated 7%)
#   adding: VGG16/group1-shard24of132.bin (deflated 7%)
#   adding: VGG16/group1-shard62of132.bin (deflated 7%)
#   adding: VGG16/group1-shard46of132.bin (deflated 7%)
#   adding: VGG16/group1-shard20of132.bin (deflated 7%)
#   adding: VGG16/group1-shard58of132.bin (deflated 7%)
#   adding: VGG16/group1-shard131of132.bin (deflated 7%)
#   adding: VGG16/group1-shard88of132.bin (deflated 7%)
#   adding: VGG16/group1-shard52of132.bin (deflated 7%)
#   adding: VGG16/group1-shard32of132.bin (deflated 7%)
#   adding: VGG16/group1-shard97of132.bin (deflated 7%)
#   adding: VGG16/group1-shard127of132.bin (deflated 7%)
#   adding: VGG16/group1-shard93of132.bin (deflated 7%)
#   adding: VGG16/group1-shard60of132.bin (deflated 7%)
#   adding: VGG16/group1-shard15of132.bin (deflated 7%)
#   adding: VGG16/group1-shard69of132.bin (deflated 7%)
#   adding: VGG16/group1-shard17of132.bin (deflated 7%)
#   adding: VGG16/group1-shard47of132.bin (deflated 7%)
#   adding: VGG16/group1-shard30of132.bin (deflated 7%)
#   adding: VGG16/group1-shard23of132.bin (deflated 7%)
#   adding: VGG16/group1-shard68of132.bin (deflated 7%)
#   adding: VGG16/group1-shard54of132.bin (deflated 7%)
#   adding: VGG16/group1-shard27of132.bin (deflated 7%)
#   adding: VGG16/group1-shard92of132.bin (deflated 7%)
#   adding: VGG16/group1-shard101of132.bin (deflated 7%)
#   adding: VGG16/group1-shard63of132.bin (deflated 7%)
#   adding: VGG16/group1-shard26of132.bin (deflated 7%)
#   adding: VGG16/group1-shard29of132.bin (deflated 7%)
#   adding: VGG16/group1-shard13of132.bin (deflated 7%)
#   adding: VGG16/group1-shard119of132.bin (deflated 7%)
#   adding: VGG16/group1-shard65of132.bin (deflated 7%)
#   adding: VGG16/group1-shard96of132.bin (deflated 7%)
#   adding: VGG16/group1-shard85of132.bin (deflated 7%)
#   adding: VGG16/group1-shard118of132.bin (deflated 7%)
#   adding: VGG16/group1-shard79of132.bin (deflated 7%)
#   adding: VGG16/group1-shard111of132.bin (deflated 7%)
#   adding: VGG16/group1-shard1of132.bin (deflated 7%)
#   adding: VGG16/group1-shard73of132.bin (deflated 7%)
#   adding: VGG16/group1-shard113of132.bin (deflated 7%)
#   adding: VGG16/group1-shard102of132.bin (deflated 7%)
#   adding: VGG16/group1-shard103of132.bin (deflated 7%)
#   adding: VGG16/group1-shard76of132.bin (deflated 7%)
#   adding: VGG16/group1-shard90of132.bin (deflated 7%)
#   adding: VGG16/group1-shard125of132.bin (deflated 7%)
#   adding: VGG16/group1-shard57of132.bin (deflated 7%)
#   adding: VGG16/group1-shard44of132.bin (deflated 7%)
#   adding: VGG16/group1-shard19of132.bin (deflated 7%)
#   adding: VGG16/group1-shard75of132.bin (deflated 7%)
#   adding: VGG16/group1-shard12of132.bin (deflated 7%)
#   adding: VGG16/group1-shard86of132.bin (deflated 7%)
#   adding: VGG16/group1-shard40of132.bin (deflated 7%)
#   adding: VGG16/group1-shard89of132.bin (deflated 7%)
#   adding: VGG16/group1-shard9of132.bin (deflated 7%)
#   adding: VGG16/group1-shard5of132.bin (deflated 7%)
#   adding: VGG16/group1-shard28of132.bin (deflated 7%)
#   adding: VGG16/group1-shard6of132.bin (deflated 7%)
#   adding: VGG16/group1-shard122of132.bin (deflated 7%)
#   adding: VGG16/group1-shard80of132.bin (deflated 7%)
#   adding: VGG16/group1-shard83of132.bin (deflated 7%)
#   adding: VGG16/group1-shard106of132.bin (deflated 7%)
#   adding: VGG16/group1-shard126of132.bin (deflated 7%)
#   adding: VGG16/group1-shard53of132.bin (deflated 7%)
#   adding: VGG16/group1-shard115of132.bin (deflated 7%)
#   adding: VGG16/group1-shard59of132.bin (deflated 7%)
#   adding: VGG16/group1-shard36of132.bin (deflated 7%)
#   adding: VGG16/group1-shard31of132.bin (deflated 7%)
#   adding: VGG16/group1-shard95of132.bin (deflated 7%)
#   adding: VGG16/group1-shard14of132.bin (deflated 7%)
#   adding: VGG16/group1-shard61of132.bin (deflated 7%)
#   adding: VGG16/group1-shard91of132.bin (deflated 7%)
#   adding: VGG16/group1-shard10of132.bin (deflated 7%)
#   adding: VGG16/group1-shard98of132.bin (deflated 7%)
#   adding: VGG16/group1-shard129of132.bin (deflated 7%)
#   adding: VGG16/group1-shard110of132.bin (deflated 7%)
#   adding: VGG16/group1-shard42of132.bin (deflated 7%)
#   adding: VGG16/group1-shard112of132.bin (deflated 7%)
#   adding: VGG16/group1-shard3of132.bin (deflated 7%)
#   adding: VGG16/group1-shard123of132.bin (deflated 7%)
#   adding: VGG16/group1-shard2of132.bin (deflated 7%)
#   adding: VGG16/group1-shard18of132.bin (deflated 7%)
#   adding: VGG16/group1-shard34of132.bin (deflated 7%)
#   adding: VGG16/group1-shard35of132.bin (deflated 7%)
#   adding: VGG16/group1-shard51of132.bin (deflated 7%)
#   adding: VGG16/group1-shard43of132.bin (deflated 7%)
#   adding: VGG16/group1-shard64of132.bin (deflated 7%)
#   adding: VGG16/group1-shard71of132.bin (deflated 7%)
#   adding: VGG16/group1-shard132of132.bin (deflated 7%)
#   adding: VGG16/group1-shard124of132.bin (deflated 7%)
#   adding: VGG16/group1-shard48of132.bin (deflated 7%)
#   adding: VGG16/group1-shard50of132.bin (deflated 7%)
#   adding: VGG16/group1-shard72of132.bin (deflated 7%)
#   adding: VGG16/group1-shard81of132.bin (deflated 7%)
#   adding: VGG16/group1-shard38of132.bin (deflated 7%)
#   adding: VGG16/group1-shard39of132.bin (deflated 7%)
#   adding: VGG16/group1-shard25of132.bin (deflated 7%)
#   adding: VGG16/group1-shard49of132.bin (deflated 7%)
#   adding: VGG16/group1-shard56of132.bin (deflated 7%)
#   adding: VGG16/group1-shard33of132.bin (deflated 7%)
#   adding: VGG16/group1-shard21of132.bin (deflated 7%)
#   adding: VGG16/group1-shard82of132.bin (deflated 7%)
#   adding: VGG16/group1-shard87of132.bin (deflated 7%)
#   adding: VGG16/group1-shard94of132.bin (deflated 7%)
#   adding: VGG16/group1-shard66of132.bin (deflated 7%)
#   adding: VGG16/group1-shard117of132.bin (deflated 7%)
#   adding: VGG16/group1-shard45of132.bin (deflated 7%)
#   adding: VGG16/group1-shard41of132.bin (deflated 7%)

# %%
mobile_model = tf.keras.applications.mobilenet.MobileNet()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 1s 0us/step

# %%
tfjs.converters.save_keras_model(mobile_model, 'MobileNet')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflowjs/converters/keras_h5_conversion.py:123: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   return h5py.File(h5file)

# %%
# !zip -r ./mobile_net.zip ./MobileNet/
# Out:
#   adding: MobileNet/ (stored 0%)
#   adding: MobileNet/model.json (deflated 95%)
#   adding: MobileNet/group1-shard5of5.bin (deflated 7%)
#   adding: MobileNet/group1-shard4of5.bin (deflated 7%)
#   adding: MobileNet/group1-shard2of5.bin (deflated 7%)
#   adding: MobileNet/group1-shard1of5.bin (deflated 7%)
#   adding: MobileNet/group1-shard3of5.bin (deflated 7%)
